# %%
import requests
import csv
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
api_link="https://rata.digitraffic.fi/api/v1/trains/{DATE}/{TRAIN_NUMBER}"

# %% [markdown]
# # **Task 1**

# %%
def fetch_train_data(date,train_number):
    url = api_link.format(DATE=date,TRAIN_NUMBER=train_number)
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch data for {date} (Status Code: {response.status_code})")
        return None

# %%
fetch_train_data("2024-11-02", 4) # test the fuction  on train_number=4 and date=2-nov-2024
# Out:
# [{'trainNumber': 4,
#   'departureDate': '2024-11-02',
#   'operatorUICCode': 10,
#   'operatorShortCode': 'vr',
#   'trainType': 'IC',
#   'trainCategory': 'Long-distance',
#   'commuterLineID': '',
#   'runningCurrently': False,
#   'cancelled': False,
#   'version': 289661200119,
#   'timetableType': 'REGULAR',
#   'timetableAcceptanceDate': '2024-05-08T10:55:08.000Z',
#   'timeTableRows': [{'stationShortCode': 'JNS',
#     'stationUICCode': 460,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:00:00.000Z',
#     'actualTime': '2024-11-02T04:01:17.000Z',
#     'differenceInMinutes': 1,
#     'causes': [],
#     'trainReady': {'source': 'KUPLA',
#      'accepted': True,
#      'timestamp': '2024-11-02T03:57:19.000Z'}},
#    {'stationShortCode': 'PLT',
#     'stationUICCode': 1070,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:00:34.000Z',
#     'actualTime': '2024-11-02T04:02:23.000Z',
#     'differenceInMinutes': 2,
#     'causes': []},
#    {'stationShortCode': 'PLT',
#     'stationUICCode': 1070,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:00:34.000Z',
#     'actualTime': '2024-11-02T04:02:23.000Z',
#     'differenceInMinutes': 2,
#     'causes': []},
#    {'stationShortCode': 'SUL',
#     'stationUICCode': 1071,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:01:14.000Z',
#     'actualTime': '2024-11-02T04:03:47.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'SUL',
#     'stationUICCode': 1071,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:01:14.000Z',
#     'actualTime': '2024-11-02T04:03:47.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'KPP',
#     'stationUICCode': 1369,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:02:31.000Z',
#     'actualTime': '2024-11-02T04:05:08.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'KPP',
#     'stationUICCode': 1369,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:02:31.000Z',
#     'actualTime': '2024-11-02T04:05:08.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'NTH',
#     'stationUICCode': 917,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:08:00.000Z',
#     'actualTime': '2024-11-02T04:08:39.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'NTH',
#     'stationUICCode': 917,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:08:00.000Z',
#     'actualTime': '2024-11-02T04:08:39.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'HSL',
#     'stationUICCode': 451,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:14:00.000Z',
#     'actualTime': '2024-11-02T04:14:30.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'HSL',
#     'stationUICCode': 451,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:14:00.000Z',
#     'actualTime': '2024-11-02T04:14:30.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'TKK',
#     'stationUICCode': 916,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:19:00.000Z',
#     'actualTime': '2024-11-02T04:18:40.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'TKK',
#     'stationUICCode': 916,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:19:00.000Z',
#     'actualTime': '2024-11-02T04:18:40.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'SÄ',
#     'stationUICCode': 918,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:22:00.000Z',
#     'actualTime': '2024-11-02T04:21:18.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'SÄ',
#     'stationUICCode': 918,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:22:00.000Z',
#     'actualTime': '2024-11-02T04:21:18.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'KIT',
#     'stationUICCode': 453,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:32:00.000Z',
#     'actualTime': '2024-11-02T04:31:54.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'KIT',
#     'stationUICCode': 453,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:33:00.000Z',
#     'actualTime': '2024-11-02T04:33:56.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'PUS',
#     'stationUICCode': 919,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': False,
#     'commercialTrack': '001',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:39:00.000Z',
#     'actualTime': '2024-11-02T04:38:01.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'PUS',
#     'stationUICCode': 919,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': False,
#     'commercialTrack': '001',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:42:00.000Z',
#     'actualTime': '2024-11-02T04:38:01.000Z',
#     'differenceInMinutes': -4,
#     'causes': []},
#    {'stationShortCode': 'KTI',
#     'stationUICCode': 966,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:56:00.000Z',
#     'actualTime': '2024-11-02T04:54:07.000Z',
#     'differenceInMinutes': -2,
#     'causes': []},
#    {'stationShortCode': 'KTI',
#     'stationUICCode': 966,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T04:57:00.000Z',
#     'actualTime': '2024-11-02T04:57:49.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'POI',
#     'stationUICCode': 965,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:02:57.000Z',
#     'liveEstimateTime': '2024-11-02T05:03:30.000Z',
#     'estimateSource': 'LIIKE_AUTOMATIC',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'POI',
#     'stationUICCode': 965,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:02:57.000Z',
#     'liveEstimateTime': '2024-11-02T05:03:30.000Z',
#     'estimateSource': 'LIIKE_AUTOMATIC',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'SR',
#     'stationUICCode': 964,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:09:00.000Z',
#     'actualTime': '2024-11-02T05:09:04.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'SR',
#     'stationUICCode': 964,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:09:00.000Z',
#     'actualTime': '2024-11-02T05:09:04.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'PAR',
#     'stationUICCode': 510,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:20:00.000Z',
#     'actualTime': '2024-11-02T05:18:53.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'PAR',
#     'stationUICCode': 510,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:21:00.000Z',
#     'actualTime': '2024-11-02T05:21:31.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'KIJ',
#     'stationUICCode': 1123,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:22:48.000Z',
#     'liveEstimateTime': '2024-11-02T05:24:50.000Z',
#     'estimateSource': 'LIIKE_AUTOMATIC',
#     'differenceInMinutes': 2,
#     'causes': []},
#    {'stationShortCode': 'KIJ',
#     'stationUICCode': 1123,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:22:48.000Z',
#     'liveEstimateTime': '2024-11-02T05:24:50.000Z',
#     'estimateSource': 'LIIKE_AUTOMATIC',
#     'differenceInMinutes': 2,
#     'causes': []},
#    {'stationShortCode': 'SPL',
#     'stationUICCode': 507,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '2',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:33:00.000Z',
#     'actualTime': '2024-11-02T05:33:28.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'SPL',
#     'stationUICCode': 507,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '2',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:34:00.000Z',
#     'actualTime': '2024-11-02T05:35:18.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'RJÄ',
#     'stationUICCode': 506,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:47:00.000Z',
#     'actualTime': '2024-11-02T05:47:17.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'RJÄ',
#     'stationUICCode': 506,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:47:00.000Z',
#     'actualTime': '2024-11-02T05:47:17.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'IM',
#     'stationUICCode': 1352,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:53:48.000Z',
#     'liveEstimateTime': '2024-11-02T05:54:30.000Z',
#     'estimateSource': 'LIIKE_AUTOMATIC',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'IM',
#     'stationUICCode': 1352,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:53:48.000Z',
#     'liveEstimateTime': '2024-11-02T05:54:30.000Z',
#     'estimateSource': 'LIIKE_AUTOMATIC',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'IMT',
#     'stationUICCode': 502,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:57:00.000Z',
#     'actualTime': '2024-11-02T05:57:53.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'IMT',
#     'stationUICCode': 502,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T05:57:00.000Z',
#     'actualTime': '2024-11-02T05:57:53.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'IMR',
#     'stationUICCode': 603,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:00:00.000Z',
#     'actualTime': '2024-11-02T06:00:56.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'IMR',
#     'stationUICCode': 603,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:02:00.000Z',
#     'actualTime': '2024-11-02T06:03:43.000Z',
#     'differenceInMinutes': 2,
#     'causes': []},
#    {'stationShortCode': 'RAH',
#     'stationUICCode': 501,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:06:00.000Z',
#     'actualTime': '2024-11-02T06:07:11.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'RAH',
#     'stationUICCode': 501,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:06:00.000Z',
#     'actualTime': '2024-11-02T06:07:11.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'JTS',
#     'stationUICCode': 499,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:13:00.000Z',
#     'actualTime': '2024-11-02T06:13:34.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'JTS',
#     'stationUICCode': 499,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:14:00.000Z',
#     'actualTime': '2024-11-02T06:14:59.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'MKO',
#     'stationUICCode': 1180,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:20:00.000Z',
#     'actualTime': '2024-11-02T06:19:27.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'MKO',
#     'stationUICCode': 1180,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:20:00.000Z',
#     'actualTime': '2024-11-02T06:19:27.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'LRS',
#     'stationUICCode': 498,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:24:00.000Z',
#     'actualTime': '2024-11-02T06:22:27.000Z',
#     'differenceInMinutes': -2,
#     'causes': []},
#    {'stationShortCode': 'LRS',
#     'stationUICCode': 498,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:24:00.000Z',
#     'actualTime': '2024-11-02T06:22:27.000Z',
#     'differenceInMinutes': -2,
#     'causes': []},
#    {'stationShortCode': 'LR',
#     'stationUICCode': 495,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:28:00.000Z',
#     'actualTime': '2024-11-02T06:26:12.000Z',
#     'differenceInMinutes': -2,
#     'causes': []},
#    {'stationShortCode': 'LR',
#     'stationUICCode': 495,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:31:00.000Z',
#     'actualTime': '2024-11-02T06:32:05.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'TAP',
#     'stationUICCode': 1276,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:36:00.000Z',
#     'actualTime': '2024-11-02T06:36:28.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'TAP',
#     'stationUICCode': 1276,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:36:00.000Z',
#     'actualTime': '2024-11-02T06:36:28.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'TRÄ',
#     'stationUICCode': 1290,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:39:00.000Z',
#     'actualTime': '2024-11-02T06:38:51.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'TRÄ',
#     'stationUICCode': 1290,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:39:00.000Z',
#     'actualTime': '2024-11-02T06:38:51.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'RAS',
#     'stationUICCode': 1222,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:42:00.000Z',
#     'actualTime': '2024-11-02T06:41:28.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'RAS',
#     'stationUICCode': 1222,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:42:00.000Z',
#     'actualTime': '2024-11-02T06:41:28.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'LÄ',
#     'stationUICCode': 487,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:46:00.000Z',
#     'actualTime': '2024-11-02T06:44:55.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'LÄ',
#     'stationUICCode': 487,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:46:00.000Z',
#     'actualTime': '2024-11-02T06:44:55.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'TA',
#     'stationUICCode': 486,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:51:00.000Z',
#     'actualTime': '2024-11-02T06:49:39.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'TA',
#     'stationUICCode': 486,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:51:00.000Z',
#     'actualTime': '2024-11-02T06:49:39.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'KJR',
#     'stationUICCode': 944,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:55:00.000Z',
#     'actualTime': '2024-11-02T06:54:08.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'KJR',
#     'stationUICCode': 944,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T06:55:00.000Z',
#     'actualTime': '2024-11-02T06:54:08.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'KPA',
#     'stationUICCode': 485,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:00:00.000Z',
#     'actualTime': '2024-11-02T06:58:57.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'KPA',
#     'stationUICCode': 485,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:00:00.000Z',
#     'actualTime': '2024-11-02T06:58:57.000Z',
#     'differenceInMinutes': -1,
#     'causes': []},
#    {'stationShortCode': 'KTH',
#     'stationUICCode': 1319,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:04:00.000Z',
#     'actualTime': '2024-11-02T07:02:17.000Z',
#     'differenceInMinutes': -2,
#     'causes': []},
#    {'stationShortCode': 'KTH',
#     'stationUICCode': 1319,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:04:00.000Z',
#     'actualTime': '2024-11-02T07:02:17.000Z',
#     'differenceInMinutes': -2,
#     'causes': []},
#    {'stationShortCode': 'UTI',
#     'stationUICCode': 484,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:05:00.000Z',
#     'actualTime': '2024-11-02T07:03:06.000Z',
#     'differenceInMinutes': -2,
#     'causes': []},
#    {'stationShortCode': 'UTI',
#     'stationUICCode': 484,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:05:00.000Z',
#     'actualTime': '2024-11-02T07:03:06.000Z',
#     'differenceInMinutes': -2,
#     'causes': []},
#    {'stationShortCode': 'KUV',
#     'stationUICCode': 1320,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:08:00.000Z',
#     'actualTime': '2024-11-02T07:05:45.000Z',
#     'differenceInMinutes': -2,
#     'causes': []},
#    {'stationShortCode': 'KUV',
#     'stationUICCode': 1320,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:08:00.000Z',
#     'actualTime': '2024-11-02T07:05:45.000Z',
#     'differenceInMinutes': -2,
#     'causes': []},
#    {'stationShortCode': 'KV',
#     'stationUICCode': 480,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '6',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:12:00.000Z',
#     'actualTime': '2024-11-02T07:09:36.000Z',
#     'differenceInMinutes': -2,
#     'causes': []},
#    {'stationShortCode': 'KV',
#     'stationUICCode': 480,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '6',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:19:00.000Z',
#     'actualTime': '2024-11-02T07:19:45.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'KRA',
#     'stationUICCode': 478,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '2',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:24:00.000Z',
#     'actualTime': '2024-11-02T07:24:12.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'KRA',
#     'stationUICCode': 478,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '2',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:24:00.000Z',
#     'actualTime': '2024-11-02T07:24:12.000Z',
#     'differenceInMinutes': 0,
#     'causes': []},
#    {'stationShortCode': 'SMÄ',
#     'stationUICCode': 1325,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:26:00.000Z',
#     'actualTime': '2024-11-02T07:26:47.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'SMÄ',
#     'stationUICCode': 1325,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:26:00.000Z',
#     'actualTime': '2024-11-02T07:26:47.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'NMÄ',
#     'stationUICCode': 1324,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:29:00.000Z',
#     'actualTime': '2024-11-02T07:30:16.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'NMÄ',
#     'stationUICCode': 1324,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:29:00.000Z',
#     'actualTime': '2024-11-02T07:30:16.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'KA',
#     'stationUICCode': 477,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:30:00.000Z',
#     'actualTime': '2024-11-02T07:31:26.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'KA',
#     'stationUICCode': 477,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:30:00.000Z',
#     'actualTime': '2024-11-02T07:31:26.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'MKA',
#     'stationUICCode': 1336,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:34:00.000Z',
#     'actualTime': '2024-11-02T07:34:54.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'MKA',
#     'stationUICCode': 1336,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:34:00.000Z',
#     'actualTime': '2024-11-02T07:34:54.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'UKÄ',
#     'stationUICCode': 105,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:38:00.000Z',
#     'actualTime': '2024-11-02T07:39:30.000Z',
#     'differenceInMinutes': 2,
#     'causes': []},
#    {'stationShortCode': 'UKÄ',
#     'stationUICCode': 105,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:38:00.000Z',
#     'actualTime': '2024-11-02T07:39:30.000Z',
#     'differenceInMinutes': 2,
#     'causes': []},
#    {'stationShortCode': 'NSL',
#     'stationUICCode': 595,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '2',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:39:30.000Z',
#     'actualTime': '2024-11-02T07:41:10.000Z',
#     'differenceInMinutes': 2,
#     'causes': []},
#    {'stationShortCode': 'NSL',
#     'stationUICCode': 595,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '2',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:39:30.000Z',
#     'actualTime': '2024-11-02T07:41:10.000Z',
#     'differenceInMinutes': 2,
#     'causes': []},
#    {'stationShortCode': 'VLH',
#     'stationUICCode': 104,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:42:00.000Z',
#     'actualTime': '2024-11-02T07:43:24.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'VLH',
#     'stationUICCode': 104,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:42:00.000Z',
#     'actualTime': '2024-11-02T07:43:24.000Z',
#     'differenceInMinutes': 1,
#     'causes': []},
#    {'stationShortCode': 'LH',
#     'stationUICCode': 100,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '4',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:47:00.000Z',
#     'actualTime': '2024-11-02T07:49:34.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'LH',
#     'stationUICCode': 100,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '4',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:49:00.000Z',
#     'actualTime': '2024-11-02T07:51:49.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HLT',
#     'stationUICCode': 1014,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:54:00.000Z',
#     'actualTime': '2024-11-02T07:57:09.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HLT',
#     'stationUICCode': 1014,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:54:00.000Z',
#     'actualTime': '2024-11-02T07:57:09.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HNN',
#     'stationUICCode': 1164,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:59:00.000Z',
#     'actualTime': '2024-11-02T08:02:01.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HNN',
#     'stationUICCode': 1164,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T07:59:00.000Z',
#     'actualTime': '2024-11-02T08:02:01.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'SIP',
#     'stationUICCode': 1254,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:02:30.000Z',
#     'actualTime': '2024-11-02T08:05:23.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'SIP',
#     'stationUICCode': 1254,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:02:30.000Z',
#     'actualTime': '2024-11-02T08:05:23.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'MLÄ',
#     'stationUICCode': 27,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:05:30.000Z',
#     'actualTime': '2024-11-02T08:08:17.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'MLÄ',
#     'stationUICCode': 27,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:05:30.000Z',
#     'actualTime': '2024-11-02T08:08:17.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'KSU',
#     'stationUICCode': 1128,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:08:30.000Z',
#     'actualTime': '2024-11-02T08:11:16.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'KSU',
#     'stationUICCode': 1128,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:08:30.000Z',
#     'actualTime': '2024-11-02T08:11:16.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HAA',
#     'stationUICCode': 13,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:12:00.000Z',
#     'actualTime': '2024-11-02T08:14:47.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HAA',
#     'stationUICCode': 13,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:12:00.000Z',
#     'actualTime': '2024-11-02T08:14:47.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'KYT',
#     'stationUICCode': 1111,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:15:00.000Z',
#     'actualTime': '2024-11-02T08:18:59.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'KYT',
#     'stationUICCode': 1111,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:15:00.000Z',
#     'actualTime': '2024-11-02T08:18:59.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'KE',
#     'stationUICCode': 20,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:16:00.000Z',
#     'actualTime': '2024-11-02T08:20:07.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'KE',
#     'stationUICCode': 20,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:16:00.000Z',
#     'actualTime': '2024-11-02T08:20:07.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'SAV',
#     'stationUICCode': 555,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:17:23.000Z',
#     'actualTime': '2024-11-02T08:21:30.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'SAV',
#     'stationUICCode': 555,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:17:23.000Z',
#     'actualTime': '2024-11-02T08:21:30.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'KRS',
#     'stationUICCode': 19,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:19:18.000Z',
#     'actualTime': '2024-11-02T08:22:42.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'KRS',
#     'stationUICCode': 19,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:19:18.000Z',
#     'actualTime': '2024-11-02T08:22:42.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HNA',
#     'stationUICCode': 1018,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:20:00.000Z',
#     'liveEstimateTime': '2024-11-02T08:22:58.000Z',
#     'estimateSource': 'LIIKE_AUTOMATIC',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HNA',
#     'stationUICCode': 1018,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:20:00.000Z',
#     'liveEstimateTime': '2024-11-02T08:22:58.000Z',
#     'estimateSource': 'LIIKE_AUTOMATIC',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'RKL',
#     'stationUICCode': 554,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:20:25.000Z',
#     'actualTime': '2024-11-02T08:23:43.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'RKL',
#     'stationUICCode': 554,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:20:25.000Z',
#     'actualTime': '2024-11-02T08:23:43.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'KVY',
#     'stationUICCode': 559,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:21:03.000Z',
#     'actualTime': '2024-11-02T08:24:32.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'KVY',
#     'stationUICCode': 559,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:21:03.000Z',
#     'actualTime': '2024-11-02T08:24:32.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HVK',
#     'stationUICCode': 1334,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:22:00.000Z',
#     'liveEstimateTime': '2024-11-02T08:25:00.000Z',
#     'estimateSource': 'LIIKE_AUTOMATIC',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HVK',
#     'stationUICCode': 1334,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:22:00.000Z',
#     'liveEstimateTime': '2024-11-02T08:25:00.000Z',
#     'estimateSource': 'LIIKE_AUTOMATIC',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HKH',
#     'stationUICCode': 556,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:22:40.000Z',
#     'actualTime': '2024-11-02T08:25:25.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'HKH',
#     'stationUICCode': 556,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:22:40.000Z',
#     'actualTime': '2024-11-02T08:25:25.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'TKL',
#     'stationUICCode': 18,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:24:00.000Z',
#     'actualTime': '2024-11-02T08:26:51.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'TKL',
#     'stationUICCode': 18,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:25:00.000Z',
#     'actualTime': '2024-11-02T08:28:31.000Z',
#     'differenceInMinutes': 4,
#     'causes': [{'categoryCode': 'M',
#       'detailedCategoryCode': 'M1',
#       'categoryCodeId': 453052490,
#       'detailedCategoryCodeId': 18546952}]},
#    {'stationShortCode': 'PLA',
#     'stationUICCode': 553,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:26:06.000Z',
#     'actualTime': '2024-11-02T08:30:14.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'PLA',
#     'stationUICCode': 553,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:26:06.000Z',
#     'actualTime': '2024-11-02T08:30:14.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'TNA',
#     'stationUICCode': 552,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:26:59.000Z',
#     'actualTime': '2024-11-02T08:31:06.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'TNA',
#     'stationUICCode': 552,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:26:59.000Z',
#     'actualTime': '2024-11-02T08:31:06.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'ML',
#     'stationUICCode': 17,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:28:00.000Z',
#     'actualTime': '2024-11-02T08:31:42.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'ML',
#     'stationUICCode': 17,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:28:00.000Z',
#     'actualTime': '2024-11-02T08:31:42.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'PMK',
#     'stationUICCode': 551,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:28:50.000Z',
#     'actualTime': '2024-11-02T08:32:20.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'PMK',
#     'stationUICCode': 551,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:28:50.000Z',
#     'actualTime': '2024-11-02T08:32:20.000Z',
#     'differenceInMinutes': 4,
#     'causes': []},
#    {'stationShortCode': 'OLK',
#     'stationUICCode': 15,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:30:00.000Z',
#     'actualTime': '2024-11-02T08:33:19.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'OLK',
#     'stationUICCode': 15,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:30:00.000Z',
#     'actualTime': '2024-11-02T08:33:19.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'KÄP',
#     'stationUICCode': 977,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:31:00.000Z',
#     'actualTime': '2024-11-02T08:33:58.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'KÄP',
#     'stationUICCode': 977,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': False,
#     'commercialTrack': '1',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:31:00.000Z',
#     'actualTime': '2024-11-02T08:33:58.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'PSL',
#     'stationUICCode': 10,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '5',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:33:00.000Z',
#     'actualTime': '2024-11-02T08:36:26.000Z',
#     'differenceInMinutes': 3,
#     'causes': []},
#    {'stationShortCode': 'PSL',
#     'stationUICCode': 10,
#     'countryCode': 'FI',
#     'type': 'DEPARTURE',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '5',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:34:00.000Z',
#     'actualTime': '2024-11-02T08:38:32.000Z',
#     'differenceInMinutes': 5,
#     'causes': []},
#    {'stationShortCode': 'HKI',
#     'stationUICCode': 1,
#     'countryCode': 'FI',
#     'type': 'ARRIVAL',
#     'trainStopping': True,
#     'commercialStop': True,
#     'commercialTrack': '7',
#     'cancelled': False,
#     'scheduledTime': '2024-11-02T08:40:00.000Z',
#     'actualTime': '2024-11-02T08:42:49.000Z',
#     'differenceInMinutes': 3,
#     'causes': []}]}]

# %%
def monthly_data_train(train_number, start_date, end_date):
    all_train_data = []
    current_date = start_date
    while current_date <= end_date:
        date_str = current_date.strftime("%Y-%m-%d")
        print(f"Fetching data for {date_str}...")
        daily_data = fetch_train_data(date_str,train_number)
        if daily_data:
            all_train_data.extend(daily_data)
        current_date += timedelta(days=1)
    return all_train_data

# %%
data=monthly_data_train(4,datetime(2024, 11, 1), datetime(2024, 11, 30))   # fetching data of train=4 from 2024-11-01 to 2024-11-30 which is requirement of given task
# Out:
# Fetching data for 2024-11-01...
# Fetching data for 2024-11-02...
# Fetching data for 2024-11-03...
# Fetching data for 2024-11-04...
# Fetching data for 2024-11-05...
# Fetching data for 2024-11-06...
# Fetching data for 2024-11-07...
# Fetching data for 2024-11-08...
# Fetching data for 2024-11-09...
# Fetching data for 2024-11-10...
# Fetching data for 2024-11-11...
# Fetching data for 2024-11-12...
# Fetching data for 2024-11-13...
# Fetching data for 2024-11-14...
# Fetching data for 2024-11-15...
# Fetching data for 2024-11-16...
# Fetching data for 2024-11-17...
# Fetching data for 2024-11-18...
# Fetching data for 2024-11-19...
# Fetching data for 2024-11-20...
# Fetching data for 2024-11-21...
# Fetching data for 2024-11-22...
# Fetching data for 2024-11-23...
# Fetching data for 2024-11-24...
# Fetching data for 2024-11-25...
# Fetching data for 2024-11-26...
# Fetching data for 2024-11-27...
# Fetching data for 2024-11-28...
# Fetching data for 2024-11-29...
# Fetching data for 2024-11-30...

# %%
def normalize_data_train(json_data):
    records = []
    for train in json_data:
        train_number = train.get("trainNumber")
        departure_date = train.get("departureDate")
        for stop in train.get("timeTableRows", []):
            record = {
                "train_number": train_number,
                "departure_date": departure_date,
                "station": stop.get("stationShortCode"),
                "type": stop.get("type"),
                "scheduled_time": stop.get("scheduledTime"),
                "actual_time": stop.get("actualTime"),
                "difference_in_minutes": stop.get("differenceInMinutes"),
            }
            records.append(record)
    return pd.DataFrame(records)

# %%
df=normalize_data_train(data)  # normalize the data of given task

# %%
df.head()
# Out:
#    train_number departure_date station       type            scheduled_time  \
# 0             4     2024-11-01     JNS  DEPARTURE  2024-11-01T04:00:00.000Z
# 1             4     2024-11-01     PLT    ARRIVAL  2024-11-01T04:00:34.000Z
# 2             4     2024-11-01     PLT  DEPARTURE  2024-11-01T04:00:34.000Z
# 3             4     2024-11-01     SUL    ARRIVAL  2024-11-01T04:01:14.000Z
# 4             4     2024-11-01     SUL  DEPARTURE  2024-11-01T04:01:14.000Z
#
#                 actual_time  difference_in_minutes
# 0  2024-11-01T04:01:07.000Z                      1
# 1  2024-11-01T04:02:12.000Z                      2
# 2  2024-11-01T04:02:12.000Z                      2
# 3  2024-11-01T04:03:34.000Z                      2
# 4  2024-11-01T04:03:34.000Z                      2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3928 entries, 0 to 3927
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   train_number           3928 non-null   int64
#  1   departure_date         3928 non-null   object
#  2   station                3928 non-null   object
#  3   type                   3928 non-null   object
#  4   scheduled_time         3928 non-null   object
#  5   actual_time            3704 non-null   object
#  6   difference_in_minutes  3928 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 214.9+ KB

# %%
output_csv = "normalized_train_data_november_2024.csv"
df.to_csv(output_csv, index=False)

# %% [markdown]
# # **Task 2**

# %%
df['actual_time'] = pd.to_datetime(df['actual_time'])
final_destination_times = df.groupby(['train_number', 'departure_date'])['actual_time'].last()
average_arrival_time = final_destination_times.mean()
print(f"The average actual arrival time at the final destination in November 2024 is: {average_arrival_time}")
# Out:
# The average actual arrival time at the final destination in November 2024 is: 2024-11-15 20:46:46.166666752+00:00
